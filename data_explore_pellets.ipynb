# %%
import pandas as pd

# Especifique o caminho do arquivo Excel
caminho_do_arquivo = 'data/dataset.xlsx'

# Carregue a tabela em um DataFrame
dados = pd.read_excel(caminho_do_arquivo)

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /home/Tairone/.local/lib/python3.9/site-packages (5.17.0)
# Requirement already satisfied: packaging in /home/Tairone/.local/lib/python3.9/site-packages (from plotly) (21.3)
# Requirement already satisfied: tenacity>=6.2.0 in /home/Tairone/.local/lib/python3.9/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/Tairone/.local/lib/python3.9/site-packages (from packaging->plotly) (3.0.9)

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /home/Tairone/.local/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /home/Tairone/.local/lib/python3.9/site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: pandas>=1.0 in /home/Tairone/.local/lib/python3.9/site-packages (from statsmodels) (1.5.2)
# Requirement already satisfied: patsy>=0.5.2 in /home/Tairone/.local/lib/python3.9/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /home/Tairone/.local/lib/python3.9/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: numpy>=1.18 in /home/Tairone/.local/lib/python3.9/site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/Tairone/.local/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /home/Tairone/.local/lib/python3.9/site-packages (from pandas>=1.0->statsmodels) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/Tairone/.local/lib/python3.9/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# Função para remover outliers usando o método IQR
def remove_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# Remover outliers das colunas relevantes
dados_filtered = remove_outliers(dados, 'Product Pellets')
dados_filtered = remove_outliers(dados_filtered, 'DDRS Rejects/Feed')
dados_filtered = remove_outliers(dados_filtered, 'SDRS Rejects/Feed')

# Extraindo as colunas relevantes do DataFrame filtrado
dates = dados_filtered['Date']
pellets = dados_filtered['Product Pellets']
ddrs_rejects = dados_filtered['DDRS Rejects/Feed']
sdrs_rejects = dados_filtered['SDRS Rejects/Feed']

# Criando DataFrame para Plotly
df_plotly = pd.DataFrame({'Date': dates, 'Pellets': pellets, 'DDRS Rejects': ddrs_rejects * 100, 'SDRS Rejects': sdrs_rejects * 100})

# Criando gráfico interativo com Plotly Express
fig = px.scatter(df_plotly, x='Pellets', y=['DDRS Rejects', 'SDRS Rejects'],
                 labels={'variable': 'Select view', 'value': 'Percentage'},
                 title='Evolution of DDRS and SDRS in relation to Product Pellets (No Outliers)',
                 hover_data=['Date'], trendline='ols')

# Exibindo o gráfico interativo
fig.show()
